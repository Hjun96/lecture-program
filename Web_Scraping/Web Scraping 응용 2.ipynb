# %% [markdown]
# **셀레니움**
# - 웹페이지 테스트 자동화를 할 수 있는 프레임워크
# - 셀레니움 사용하면 완전한 형태의 웹 페이지 소스를 볼 수 있기 때문에 스크래핑할 때 유용

# %% [markdown]
# **사용 예**
# - 자바스크립트가 동적으로 만든 데이터 스크래핑할 때
# - 사이트의 다양한 HTML 요소에 클릭, 키보드 입력 등 이벤트를 줄 때

# %% [markdown]
# **사용 방법**
# - 셀레니움을 사용하려면 사용중인 웹 브라우저의 드라이버 파일을 다운로드해야 함
# - 크롬 드라이버 파일 다운로드 받기
# ```
# chrome://version/ 버전 확인
# https://chromedriver.chromium.org/downloads 에서 chrome 버전과 운영체제에 맞는 드라이버 다운로드
# 압축 푼 뒤 응용 프로그램을 현재 작업 디렉토리에 카피
# ```

# %% [markdown]
# - selenium 설치
# ```
# conda install selenium
# ```

# %% [markdown]
# * 참고사이트
# ```
# https://www.selenium.dev/documentation/webdriver/
# ```

# %%
from IPython.display import Image
Image('webdriver.png')

# %%
import selenium

# %%
from selenium import webdriver

# %%
# driver = webdriver.Chrome(executable_path="./chromedriver")

# %%
driver = webdriver.Chrome() # driver가 있는 path를 넣어줄 수 있음

# %%
driver.get("http://naver.com")

# %%
driver.back()

# %%
driver.forward()

# %%
driver.refresh()

# %%
driver.close() # browser가 종료

# %%
driver.quit() # browser, driver 종료

# %% [markdown]
# - 더 자세한 내용은
# ```
# https://www.selenium.dev/documentation/webdriver/elements/
# ```

# %% [markdown]
# **find_element_by_tag_name**

# %%
driver = webdriver.Chrome()
driver.get("http://naver.com")

# %%
# find_element_by_tag_name 를 통해 a tag에 접근
# href 정보까지도 조회
elem = driver.find_element_by_tag_name('a')

elem.get_attribute('href')
# Out:
# 'https://www.naver.com/#newsstand'

# %%
# 여러 tag를 가져올 때는 find_elements_by_tag_name
elems = driver.find_elements_by_tag_name('a')
for elem in elems:
    print(elem.get_attribute('href'))
# Out:
# https://www.naver.com/#newsstand
# https://www.naver.com/#themecast
# https://www.naver.com/#timesquare
# https://www.naver.com/#shopcast
# https://www.naver.com/#account
# https://whale.naver.com/banner/details/security/?=main&wpid=RydDy7
# https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe
# https://www.naver.com/
# https://help.naver.com/support/welcomePage/guide.help
# https://jr.naver.com/
# https://happybean.naver.com/
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://help.naver.com/support/alias/search/word/word_29.naver
# https://help.naver.com/support/alias/search/word/word_29.naver
# https://help.naver.com/support/service/main.help?serviceNo=605&categoryNo=1991
# https://www.naver.com/#
# https://www.naver.com/#
# https://help.naver.com/support/alias/search/word/word_16.naver
# https://www.naver.com/#
# https://help.naver.com/support/alias/search/word/word_16.naver
# https://nid.naver.com/nidlogin.login
# https://help.naver.com/support/alias/search/word/word_16.naver
# https://www.naver.com/#
# https://help.naver.com/alias/search/word/word_17.naver
# https://help.naver.com/support/contents/contents.help?serviceNo=605&categoryNo=18215
# https://www.naver.com/#
# https://campaign.naver.com/memory_1030/
# https://mail.naver.com/
# https://section.cafe.naver.com/
# https://section.blog.naver.com/
# https://kin.naver.com/
# https://shopping.naver.com/
# https://shoppinglive.naver.com/home
# https://order.pay.naver.com/home
# https://tv.naver.com/
# https://dict.naver.com/
# https://news.naver.com/
# https://finance.naver.com/
# https://land.naver.com/
# https://map.naver.com/
# https://vibe.naver.com/
# https://search.shopping.naver.com/book/home
# https://comic.naver.com/
# https://www.naver.com/#
# https://www.naver.com/more.html
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://weather.naver.com/today/09650108?cpName=KMA
# https://me.naver.com/tab/news.nhn
# https://weather.naver.com/
# https://mycar.naver.com/
# https://game.naver.com/
# https://booking.naver.com/booked/list
# https://contents.premium.naver.com/
# http://plus.naver.com/
# https://news.naver.com/
# https://datalab.naver.com/
# https://search.shopping.naver.com/book/home
# https://memo.naver.com/
# https://band.us/
# https://land.naver.com/
# https://sports.news.naver.com/
# https://series.naver.com/
# https://serieson.naver.com/
# https://expert.naver.com/
# https://movie.naver.com/
# https://audioclip.naver.com/
# https://office.naver.com/
# https://whale.naver.com/
# https://novel.naver.com/
# https://comic.naver.com/
# https://in.naver.com/
# https://contact.naver.com/
# https://finance.naver.com/
# https://map.naver.com/
# https://terms.naver.com/
# https://calendar.naver.com/
# https://clovadubbing.naver.com/
# https://papago.naver.com/
# https://post.naver.com/
# https://academic.naver.com/
# https://flight.naver.com/
# https://hotels.naver.com/
# https://keep.naver.com/
# https://www.modoo.at/
# https://mybox.naver.com/
# https://entertain.naver.com/home
# https://www.vlive.tv/
# https://vibe.naver.com/
# https://dict.naver.com/
# https://ko.dict.naver.com/
# https://endic.naver.com/
# https://ja.dict.naver.com/
# https://zh.dict.naver.com/
# https://hanja.dict.naver.com/
# https://dict.naver.com/
# https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y
# https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013541640
# http://news.naver.com/
# http://entertain.naver.com/home
# http://sports.news.naver.com/
# http://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101
# http://newsstand.naver.com/
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/config.html
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=109
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=022
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=003
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=366
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=314
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=030
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=422
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=002
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=005
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=326
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=029
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=052
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=308
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=044
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=117
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=993
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=946
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=811
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=913
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=328
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=943
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=984
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=421
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=997
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=904
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=055
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=079
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=092
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=028
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=011
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=139
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=241
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=023
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=327
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=047
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=020
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=293
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=014
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=368
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=945
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=956
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=094
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=822
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=803
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=340
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=942
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=140
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=905
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=073
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=076
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=277
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=006
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=215
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=009
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=025
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=008
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=214
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=032
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=038
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=930
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=330
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=056
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=991
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=363
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=345
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=988
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=808
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=813
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=995
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=911
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=815
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=021
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=057
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=018
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=031
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=081
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=016
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=015
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=906
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=961
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=296
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=819
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=312
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=812
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=921
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=994
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=682
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=805
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=823
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=920
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=354
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=903
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=968
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=989
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/?list=&pcode=396
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# http://newsstand.naver.com/config.html
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://blog.naver.com/living_food/222909272482
# https://blog.naver.com/living_food/222909272482
# https://blog.naver.com/living_food/222909263601
# https://blog.naver.com/living_food/222909263601
# https://blog.naver.com/heejoomam/222906331215
# https://blog.naver.com/heejoomam/222906331215
# https://blog.naver.com/charm77h/222889233078
# https://blog.naver.com/charm77h/222889233078
# https://blog.naver.com/hamami10/222911000255
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:139, in WebElement.get_attribute(self, name)
#     137 attributeValue = ''
#     138 if self._w3c:
# --> 139     attributeValue = self.parent.execute_script(
#     140         "return (%s).apply(null, arguments);" % getAttribute_js,
#     141         self, name)
#     142 else:
#     143     resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:634, in WebDriver.execute_script(self, script, *args)
#     631 else:
#     632     command = Command.EXECUTE_SCRIPT
# --> 634 return self.execute(command, {
#     635     'script': script,
#     636     'args': converted_args})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=107.0.5304.88)

# %%
driver.quit()

# %% [markdown]
# **find_element_by_id**

# %%
driver = webdriver.Chrome()
driver.get("http://naver.com")

# %%
elem = driver.find_element_by_id('query')

# %%
elem.send_keys("파이썬")

# %%
from selenium.webdriver.common.keys import Keys
elem.send_keys(Keys.ENTER)

# %%
driver.quit()

# %% [markdown]
# **find_element_by_name**

# %%
driver = webdriver.Chrome()
driver.get("http://naver.com")

# %%
elem = driver.find_element_by_name('query')
elem.send_keys("파이썬")

# %%
elem = driver.find_element_by_id('search_btn')
elem.click()

# %%
driver.back()

# %% [markdown]
# **find_element_by_xpath**

# %%
elem = driver.find_element_by_name('query')
elem.send_keys("파이썬")

# %%
elem = driver.find_element_by_xpath('//*[@id="search_btn"]')
elem.click()

# %%
driver.quit()

# %%
# Element를 찾는데 필요한 함수들
# driver.find_element_by_id
# driver.find_element_by_name
# driver.find_element_by_tag_name
# driver.find_element_by_xpath
# driver.find_element_by_css_selector

# %% [markdown]
# ### Workshop 1
# **네이버 로그인**

# %%
import time

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47')

driver = webdriver.Chrome(options=options)

# 네이버 사이트 이동
driver.get("http://naver.com")

# %%
# 로그인 버튼
elem = driver.find_element_by_css_selector('a.link_login')
elem.click()

# %%
# id/ pw 입력
elem = driver.find_element_by_id('id')
elem.send_keys("xxxx")
time.sleep(2)

elem = driver.find_element_by_id('pw')
elem.send_keys('yyyy')
time.sleep(1)

# 로그인 버튼
elem = driver.find_element_by_id('log.login')
elem.click()

# %%
# 종료
driver.quit()

# %% [markdown]
# ### Workshop 2

# %% [markdown]
# **구글 이미지 검색**

# %% [markdown]
# - 이미지 한장 저장

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47')

driver = webdriver.Chrome(options=options)

# 구글 이미지검색 사이트 이동
driver.get("https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl")

# 검색
keyword = '딸기'
elem = driver.find_element_by_name('q')
elem.send_keys(keyword)
elem.submit() # elem.send_keys(Keys.ENTER) 와 동일

# 작은 이미지 클릭
image_elem= driver.find_element_by_css_selector('img.rg_i.Q4LuWd')
image_elem.click()

# 오른쪽에 있는 큰 이미지의 주소를 획득
image_elem = driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img')
image_url = image_elem.get_attribute('src')
print(image_url)

# 이미지 주소로 request 해서 응답받은 이미지를 저장
import requests

user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47"

headers = {"User-Agent" : user_agent}
response = requests.get(image_url, headers)
response.raise_for_status()

with open('./strawberry/1.jpg', 'wb') as fd:
            fd.write(response.content)
# Out:
# data:image/jpeg;base64,...
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Input In [28], in <cell line: 30>()
#      27 user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47"
#      29 headers = {"User-Agent" : user_agent}
# ---> 30 response = requests.get(image_url, headers)
#      31 response.raise_for_status()
#      33 with open('./strawberry/1.jpg', 'wb') as fd:
#
# File ~\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:639, in Session.send(self, request, **kwargs)
#     636 hooks = request.hooks
#     638 # Get the appropriate adapter to use
# --> 639 adapter = self.get_adapter(url=request.url)
#     641 # Start time (approximately) of the request
#     642 start = preferred_clock()
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:732, in Session.get_adapter(self, url)
#     729         return adapter
#     731 # Nothing matches :-/
# --> 732 raise InvalidSchema("No connection adapters were found for {!r}".format(url))
#
# InvalidSchema: No connection adapters were found for 'data:image/jpeg;base64,...'

# %%
selenium.__version__
# Out:
# '3.141.0'

# %%
driver.quit()

# %% [markdown]
# - 이미지 여러장 저장

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47')

driver = webdriver.Chrome(options=options)

# 구글 이미지검색 사이트 이동
driver.get("https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl")

# 검색
keyword = '감자'
elem = driver.find_element_by_name('q')
elem.send_keys(keyword)
elem.submit() # elem.send_keys(Keys.ENTER) 와 동일

# 작은 이미지 클릭
image_elems= driver.find_elements_by_css_selector('img.rg_i.Q4LuWd')

count = 1
for image_elem in image_elems:
    image_elem.click()
    time.sleep(2)

    # 오른쪽에 있는 큰 이미지의 주소를 획득
    image_elem = driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img')
    image_url = image_elem.get_attribute('src')
    print(image_url)

    # 이미지 주소로 request 해서 응답받은 이미지를 저장
    import requests

    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47"

    headers = {"User-Agent" : user_agent}
    response = requests.get(image_url, headers)
    response.raise_for_status()

    with open('./potato/{}.jpg'.format(count), 'wb') as fd:
                fd.write(response.content)
    count += 1
    if count > 10:
        break
# Out:
# http://health.chosun.com/site/data/img_dir/2020/05/07/2020050702573_0.jpg
# https://mediahub.seoul.go.kr/wp-content/uploads/2016/09/61a2981f41200ac8c513a3cbc0010efe.jpg
# https://static.wikia.nocookie.net/nutri/images/a/af/%EA%B0%90%EC%9E%90.png/revision/latest/scale-to-width-down/1200?cb=20160225185937&path-prefix=ko
# https://img.hankyung.com/photo/202205/01.29875486.1.jpg
# https://www.shinsegaegroupnewsroom.com/wp-content/uploads/2020/07/%EC%9D%B4%EB%A7%88%ED%8A%B813_%EB%B3%B8%EB%AC%B801.png
# http://kormedi.com/wp-content/uploads/2021/07/gettyimages-1255196477-580x409.jpg
# https://cdn.travie.com/news/photo/202104/21806_10684_4721.jpg
# https://file.mk.co.kr/meet/neds/2022/03/image_readtop_2022_232180_16471681304973401.jpg
# https://health.chosun.com/site/data/img_dir/2022/03/02/2022030201576_0.jpg
# https://cdn.manzlab.com/news/photo/201808/1459_2985_4311.jpg

# %%
driver.quit()

# %% [markdown]
# - 사용자의 Scroll 반영

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47')

driver = webdriver.Chrome(options=options)

# 구글 이미지검색 사이트 이동
driver.get("https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl")

# 검색
keyword = '감자'
elem = driver.find_element_by_name('q')
elem.send_keys(keyword)
elem.submit() # elem.send_keys(Keys.ENTER) 와 동일

# Java Script의 스크롤 기능을 통해서 더 많은 이미지를 가져옴
prev_height = driver.execute_script('return document.body.scrollHeight')
print(prev_height)

while True:
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(1)
    curr_height = driver.execute_script('return document.body.scrollHeight')
    print(curr_height)
    if prev_height == curr_height:
        break
    prev_height = curr_height

# 작은 이미지 클릭
image_elems= driver.find_elements_by_css_selector('img.rg_i.Q4LuWd')

count = 1
for image_elem in image_elems:
    image_elem.click()
    time.sleep(2)

    # 오른쪽에 있는 큰 이미지의 주소를 획득
    image_elem = driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img')
    image_url = image_elem.get_attribute('src')
    print(image_url)

    # 이미지 주소로 request 해서 응답받은 이미지를 저장
    import requests

    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47"

    headers = {"User-Agent" : user_agent}
    response = requests.get(image_url, headers)
    response.raise_for_status()

    with open('./potato/{}.jpg'.format(count), 'wb') as fd:
                fd.write(response.content)
    count += 1
    if count > 30:
        break
# Out:
# 3270
# 6428
# 12494
# 18802
# 18802
# http://health.chosun.com/site/data/img_dir/2020/05/07/2020050702573_0.jpg
# https://mediahub.seoul.go.kr/wp-content/uploads/2016/09/61a2981f41200ac8c513a3cbc0010efe.jpg
# https://static.wikia.nocookie.net/nutri/images/a/af/%EA%B0%90%EC%9E%90.png/revision/latest/scale-to-width-down/1200?cb=20160225185937&path-prefix=ko
# https://img.hankyung.com/photo/202205/01.29875486.1.jpg
# https://www.shinsegaegroupnewsroom.com/wp-content/uploads/2020/07/%EC%9D%B4%EB%A7%88%ED%8A%B813_%EB%B3%B8%EB%AC%B801.png
# http://kormedi.com/wp-content/uploads/2021/07/gettyimages-1255196477-580x409.jpg
# https://cdn.travie.com/news/photo/202104/21806_10684_4721.jpg
# https://cdn.manzlab.com/news/photo/201808/1459_2985_4311.jpg
# https://file.mk.co.kr/meet/neds/2022/03/image_readtop_2022_232180_16471681304973401.jpg
# https://health.chosun.com/site/data/img_dir/2022/03/02/2022030201576_0.jpg
# https://t1.daumcdn.net/thumb/R720x0/?fname=http://t1.daumcdn.net/brunch/service/user/3mm/image/sknMyUB4sU-_FplAP6ZeainEGF8
# https://www.tefal.co.kr/medias/?context=bWFzdGVyfHJvb3R8MTY5OTB8aW1hZ2UvanBlZ3xoZGMvaDI4LzE0MDcwMjQ4Mjc1OTk4LmpwZ3wyOTBmNDZmYmU5NTUwYWE4YmQwMjQyOTdmZjg4YWExYmE2YTQxNjlhYWQ4YmUxNjY1MTcwMjE5MGMwYzBhODQ0
# https://image.dongascience.com/Photo/2021/08/53df2dd5a36c58b02c0c2353f65cb5c8.png
# https://img-cf.kurly.com/shop/data/goodsview/20210218/gv30000159355_1.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/234_Solanum_tuberosum_L.jpg/250px-234_Solanum_tuberosum_L.jpg
# https://newsimg.sedaily.com/2019/12/02/1VRX2UQHET_1.jpg
# https://images.mypetlife.co.kr/content/uploads/2019/10/09152556/lars-blankers-B0s3Xndk6tw-unsplash-1024x683.jpg
# https://blog.kakaocdn.net/dn/cwMiBr/btqDMj3d63f/QKs3YBc6S3blMD38nnwtl0/img.jpg
# https://image.news1.kr/system/photos/2019/4/26/3618614/article.jpg/dims/optimize
# https://img-cf.kurly.com/shop/data/goodsview/20210628/gv30000197759_1.jpg
# https://recipe1.ezmember.co.kr/cache/recipe/2022/02/08/ff66cfd71a3b9d41b26142a410b0cc4d1.jpg
# https://cdn.huffingtonpost.kr/news/photo/201601/21945_42769.jpeg
# https://mblogthumb-phinf.pstatic.net/MjAyMDA0MjlfOTkg/MDAxNTg4MTcxNjQ4NTky.3bpJ9I02zfdkXhcRurVno8fSdGBwpmrDcGkd6YahV6Qg.Z_GjMTNXiHu4iEtZhsHGov3M_lwY62pD_etwP2HB8uEg.JPEG.juheang/compressed_potato-products_800x600.jpg?type=w800
# https://pds.joongang.co.kr/news/component/htmlphoto_mmdata/202010/14/de077442-5c16-47a3-9705-c09f293050a0.jpg
# https://recipe1.ezmember.co.kr/cache/recipe/2021/01/01/66783e2b5ebd0d1936156fe20e20e7561.jpg
# https://blog.kakaocdn.net/dn/dJSVwV/btrctuINHBf/RgU1SC94TekVy6hiijpct1/img.png
# https://image.homeplus.kr/td/a5103572-8790-4016-80ac-cdbdd73c47bb
# https://contents.lotteon.com/itemimage/_v140655/LO/19/70/97/82/44/_1/97/09/78/24/5/LO1970978244_1970978245_1.jpg/dims/optimize/dims/resizemc/400x400
# https://tongsangnews.kr/webzine/2110/assets/images/sub/sub4_2_1.jpg
# https://post-phinf.pstatic.net/MjAxOTA3MDhfODEg/MDAxNTYyNTUyNDU3MjU2.re47TUbcUytgBBT6Pcsnpqz2ZYELS0jRWNm0N_yoYb0g.GEH8hUENjObjG77330lGLIF5x6ncy6vd02brSBN46cog.JPEG/GettyImages-a11228264.jpg?type=w1200

# %%
driver.quit()

# %% [markdown]
# ### Workshop 3

# %% [markdown]
# **구글 무비**
# - https://play.google.com/store/movies/top
# - 스크롤된 모든 데이터에 대해
# - 가격이 할인된 영화만 출력하되
# - 출력 양식 : 영화제목, 할인전/후 가격, 링크

# %%
from bs4 import BeautifulSoup

# %%
# 1. 첫 화면 접속
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47')

driver = webdriver.Chrome(options=options)

# 구글 이미지검색 사이트 이동
driver.get("https://play.google.com/store/movies/top")

# 2. 페이지 스크롤
# Java Script의 스크롤 기능을 통해서 더 많은 이미지를 가져옴
prev_height = driver.execute_script('return document.body.scrollHeight')
print(prev_height)

while True:
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(1)
    curr_height = driver.execute_script('return document.body.scrollHeight')
    print(curr_height)
    if prev_height == curr_height:
        break
    prev_height = curr_height

# 3. 필요한 정보 가져오기 위해 구문 분석
soup = BeautifulSoup(driver.page_source, 'lxml')

# print(soup.prettify())

movies = soup.select('div.VfPpkd-EScbFb-JIbuQc.UVEnyf')

print(len(movies))

count = 0
for movie in movies:
    # 영화제목
    title = movie.select_one('div.Epkrse')
    title = title.text

    # 할인 전 가격
    original_price= movie.select_one('span.SUZt4c.P8AFK')
    if original_price: 
        original_price = original_price.text

    else: # 할인 전 가격이 없으면 세일하는 항목이 아님
        continue
        
    # 할인 후 가격
    discount_price= movie.select_one('span.VfPpfd.VixbEe')
    discount_price = discount_price.text


    # 링크 정보
    link = movie.select_one('a.Si6A0c.ZD8Cqc')
    link = 'https://play.google.com' + link['href']

    
    print('제목 : ', title)
    print('할인전 가격 : ', original_price)
    print('할인후 가격 : ', discount_price)
    print('링크 : ', link)
    print('-'*100)
    count += 1
print(count)   

driver.quit()
# Out:
# 2160
# 2882
# 3270
# 3270
# 120
# 제목 :  탑건 2 무비 컬렉션
# 할인전 가격 :  ₩13,500
# 할인후 가격 :  ₩12,000
# 링크 :  https://play.google.com/store/movies/details/%ED%83%91%EA%B1%B4_2_%EB%AC%B4%EB%B9%84_%EC%BB%AC%EB%A0%89%EC%85%98?id=1aLgJ4syNGk.P
# ----------------------------------------------------------------------------------------------------
# 제목 :  해리포터풀패키지(1-7B)
# 할인전 가격 :  ₩36,000
# 할인후 가격 :  ₩30,400
# 링크 :  https://play.google.com/store/movies/details/%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0%ED%92%80%ED%8C%A8%ED%82%A4%EC%A7%80_1_7B?id=oV2yIteiUjY.P
# ----------------------------------------------------------------------------------------------------
# 제목 :  락다운 213주
# 할인전 가격 :  ₩7,000
# 할인후 가격 :  ₩5,000
# 링크 :  https://play.google.com/store/movies/details/%EB%9D%BD%EB%8B%A4%EC%9A%B4_213%EC%A3%BC?id=1xGYLHUpk4E.P
# ----------------------------------------------------------------------------------------------------
# 제목 :  리볼버
# 할인전 가격 :  ₩7,000
# 할인후 가격 :  ₩5,000
# 링크 :  https://play.google.com/store/movies/details/%EB%A6%AC%EB%B3%BC%EB%B2%84?id=pB98Q-Rx6pM.P
# ----------------------------------------------------------------------------------------------------
# 제목 :  해리포터풀패키지(1-7B)
# 할인전 가격 :  ₩36,000
# 할인후 가격 :  ₩30,400
# 링크 :  https://play.google.com/store/movies/details/%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0%ED%92%80%ED%8C%A8%ED%82%A4%EC%A7%80_1_7B?id=oV2yIteiUjY.P
# ----------------------------------------------------------------------------------------------------
# 제목 :  해리포터 시리즈 완결 패키지
# 할인전 가격 :  ₩36,000
# 할인후 가격 :  ₩18,900
